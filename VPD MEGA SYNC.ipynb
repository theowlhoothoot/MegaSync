# %%
from mega import Mega
from mega.crypto import base64_to_a32, base64_url_decode, decrypt_attr, decrypt_key
from typing import Tuple

import math
import re
import json
import logging
import secrets
from pathlib import Path
import hashlib
from Crypto.Cipher import AES
from Crypto.PublicKey import RSA
from Crypto.Util import Counter
import os
import random
import binascii
import tempfile
import shutil

import requests
from tenacity import retry, wait_exponential, retry_if_exception_type

from crypto import (a32_to_base64, encrypt_key, base64_url_encode,
                     encrypt_attr, base64_to_a32, base64_url_decode,
                     decrypt_attr, a32_to_str, get_chunks, str_to_a32,
                     decrypt_key, mpi_to_int, stringhash, prepare_key, make_id,
                     makebyte, modular_inverse)

mega = Mega()
email = ""
password = ""
m = mega.login(email, password)

def get_nodes_in_shared_folder(root_folder: str) -> dict:
    data = [{"a": "f", "c": 1, "ca": 1, "r": 1}]
    response = requests.post(
        "https://g.api.mega.co.nz/cs",
        params={'id': 0,  # self.sequence_num
                'n': root_folder},
        data=json.dumps(data)
    )
    json_resp = response.json()
    return json_resp[0]["f"]

def parse_folder_url(url: str) -> Tuple[str, str]:
    "Returns (public_handle, key) if valid. If not returns None."
    REGEXP1 = re.compile(r"mega.[^/]+/folder/([0-z-_]+)#([0-z-_]+)(?:/folder/([0-z-_]+))*")
    REGEXP2 = re.compile(r"mega.[^/]+/#F!([0-z-_]+)[!#]([0-z-_]+)(?:/folder/([0-z-_]+))*")
    m = re.search(REGEXP1, url)
    if not m:
        m = re.search(REGEXP2, url)
    if not m:
        print("Not a valid URL")
        return None
    root_folder = m.group(1)
    key = m.group(2)
    # You may want to use m.group(-1)
    # to get the id of the subfolder
    return (root_folder, key)

def decrypt_node_key(key_str: str, shared_key: str) -> Tuple[int, ...]:
    encrypted_key = base64_to_a32(key_str.split(":")[1])
    return decrypt_key(encrypted_key, shared_key)

def _download_file(file_data, file_key, file_name):
    print (file_name)
    file_url = file_data['g']
    file_size = file_data['s']
    k = (file_key[0] ^ file_key[4], file_key[1] ^ file_key[5],
    file_key[2] ^ file_key[6], file_key[3] ^ file_key[7])
    iv = file_key[4:6] + (0, 0)
    meta_mac = file_key[6:8]
            
    attribs = base64_url_decode(file_data['at'])
    attribs = decrypt_attr(attribs, file_key)
        
    input_file = requests.get(file_url, stream=True).raw

    with tempfile.NamedTemporaryFile(mode='w+b',prefix='megapy_',delete=False) as temp_output_file: 
        k_str = a32_to_str(k)
        counter = Counter.new(128,initial_value=((iv[0] << 32) + iv[1]) << 64)
        aes = AES.new(k_str, AES.MODE_CTR, counter=counter)

        mac_str = '\0' * 16
        mac_encryptor = AES.new(k_str, AES.MODE_CBC,mac_str.encode("utf8"))
        iv_str = a32_to_str([iv[0], iv[1], iv[0], iv[1]])

        for chunk_start, chunk_size in get_chunks(file_size):
            chunk = input_file.read(chunk_size)
            chunk = aes.decrypt(chunk)
            temp_output_file.write(chunk)

            encryptor = AES.new(k_str, AES.MODE_CBC, iv_str)
            for i in range(0, len(chunk) - 16, 16):
                block = chunk[i:i + 16]
                encryptor.encrypt(block)

                # fix for files under 16 bytes failing
            if file_size > 16:
                i += 16
            else:
                i = 0

            block = chunk[i:i + 16]
            if len(block) % 16:
                block += b'\0' * (16 - (len(block) % 16))
                    
            #mac_str = mac_encryptor.encrypt(encryptor.encrypt(block))

            #file_info = os.stat(temp_output_file.name)
            #file_mac = str_to_a32(mac_str)
            # check mac integrity
            #if (file_mac[0] ^ file_mac[1],file_mac[2] ^ file_mac[3]) != meta_mac:
            #    raise ValueError('Mismatched mac')
    
    output_path = Path(file_name)
    shutil.move(temp_output_file.name, output_path)

# %%
import re, requests, json
import os
from os.path import exists
import threading
import queue

base_name = r"D:/Sync2"
base_url = "https://mega.nz/folder/gp12RQaK#SeztTrf6H3cUuJPWZEbuKQ"

(root_folder, shared_enc_key) = parse_folder_url(base_url)
#(root_folder, shared_enc_key) = parse_folder_url("https://mega.nz/folder/8pNlHawJ#J2m2aZqsEmGGL_frGf4veQ")


folderSyncLocation = r"D:\SyncTest"


shared_key = base64_to_a32(shared_enc_key)
nodes = get_nodes_in_shared_folder(root_folder)

folder_structure = {}
files = {}
total_file_count = len(nodes)
    
file_count = 0
downloaded_count = 0

def downloadSomething(root_folder: str, file_data) -> dict:
    response = requests.post(
        "https://g.api.mega.co.nz/cs",
        params={'id': 0,  # self.sequence_num
                'n': root_folder},
        data=json.dumps(file_data)
    )
    json_resp = response.json()
    return json_resp[0]

def process_node(node):
    global downloaded_count
    global base_id
    key = decrypt_node_key(node["k"], shared_key)
    
    
    isFile = None
    
    if node["t"] == 0: # Is a file
        isFile = True
        k = (key[0] ^ key[4], key[1] ^ key[5], key[2] ^ key[6], key[3] ^ key[7])
    elif node["t"] == 1: # Is a folder
        isFile = False
        k = key
        
    attrs = decrypt_attr(base64_url_decode(node["a"]), k)
    
    file_name = attrs["n"]
    file_id = node["h"]
    
    
    if (file_id != base_id):
        file_data = [{ 'a': 'g', 'g': 1, 'n': node['h'] }]

        if (node["p"] == base_id): 
            if (isFile):
                filePath = "{0}/{1}".format(base_name, file_name)
                
                if not (exists(filePath)):
                    #print ("Downloading {0}/{1}".format(base_name, file_name))
                    
                    something = downloadSomething(root_folder,file_data)
                    
                    try:
                        _download_file(something,key, filePath)
                    except Exception as e:
                        print ("Error on " + file_name, e)

            else:
                folder_path = "{0}/{1}".format(base_name, file_name)
                files[file_id] = folder_path
                
                if not (exists(folder_path)):
                    path = os.path.join(base_name, file_name)
                    os.mkdir(path)
        else:
            if (isFile):
                filePath = "{0}/{1}".format(files[node["p"]], file_name)
                if not (exists(filePath)):
                    #print ("Downloading {0}/{1}".format(files[node["p"]], file_name))
                    something = downloadSomething(root_folder,file_data)
                    try:
                        _download_file(something,key, filePath)
                    except Exception as e:
                        print ("Error on " + file_name, e)
                else:
                    pass

            else:                
                folder_path = "{0}/{1}".format(files[node["p"]], file_name)
                files[file_id] = folder_path
                
                if not (exists(folder_path)):
                    path = os.path.join(files[node["p"]], file_name)
                    os.mkdir(path)
        
    downloaded_count += 1
    
    print (downloaded_count,"/",total_file_count, " files have been checked")

                    
def main():
    q = queue.Queue()

    for node in nodes:

        process_node(node)

        


def getBaseFolderID():
    global downloaded_count
    node = nodes[0]
    
    key = decrypt_node_key(node["k"], shared_key)
    
    
    isFile = None
    
    if node["t"] == 0: # Is a file
        isFile = True
        k = (key[0] ^ key[4], key[1] ^ key[5], key[2] ^ key[6], key[3] ^ key[7])
    elif node["t"] == 1: # Is a folder
        isFile = False
        k = key
        
    attrs = decrypt_attr(base64_url_decode(node["a"]), k)
    
    file_name = attrs["n"]
    file_id = node["h"]
    
    downloaded_count += 1

    return file_id

base_id = getBaseFolderID()

#main()

# %%
import queue
import threading

num_worker_threads = 10

def do_work(item):
    process_node(item)

def worker():
    while True:
        item = q.get()
        if item is None:
            break
        do_work(item)
        q.task_done()

q = queue.Queue()

threads = []

for i in range(num_worker_threads):
    t = threading.Thread(target=worker)
    t.start()
    threads.append(t)


for item in nodes:
    q.put(item)

# block until all tasks are done
q.join()

print('stopping workers!')

# stop workers
for i in range(num_worker_threads):
    q.put(None)

for t in threads:
    t.join()
# Out:
# 23 / 1895  files have been checked
# 4 / 1895   files have been checked
# / 18955 / 1895  files have been checked
#  6 / 1895  files have been checked
# 7 files have been checked
#  / 1895  files have been checked
# 8 / 1895  files have been checked
# 9 / 1895 10 / 189511 / 1895  files have been checked
#  files have been checked12 13/ 1895  files have been checked
#  /  14  files have been checked15 161895 17   files have been checked
#
# / /189518/ 1895  /    files have been checked files have been checked
# 1895  files have been checked
# / 189519  files have been checked
# /20
#  / 1895 21221895   files have been checked
# /  files have been checked1895 23 / 1895
#   files have been checked24 1895  files have been checked25 / 1895
# 26  files have been checked
#  / 1895  / 1895  files have been checked
# /2728 files have been checked
#  29 files have been checked
#
#  /30 /  18951895  31  files have been checked
# // 1895 1895  32 / 1895  files have been checked
#  /33 files have been checked1895 files have been checked
# 34   files have been checked35
#   files have been checked
#  1895 36// files have been checked
#
# / / 1895 1895  files have been checked
# 37 files have been checked1895  files have been checked
#
#  / 18951895  files have been checked
# 3839 / 1895  files have been checked
#  40 / 1895  files have been checked
#  files have been checked / 1895
#   files have been checked41 / 42
# 4344 1895  files have been checked
#  / / 1895 / 1895  files have been checked
#  454647 files have been checked / 48 1895 / 1895  files have been checked
# 189549 files have been checked   files have been checked
#  50 /51
# /
# 52/ 1895  / 1895 / files have been checked
#     files have been checked189518951895
#   files have been checked
# 53
#   files have been checked
#   54 5556 / 1895  files have been checked
# 57 / 1895  files have been checked
# / 1895  files have been checked
# 5859 / 1895  files have been checked
#  / 1895  files have been checked
# // 60  18951895 61/ /1895  files have been checked62 /  files have been checked
#    files have been checked6364
#
#  1895/ 1895   / 1895  files have been checked files have been checked/ 1895  files have been checked
#  files have been checked65 1895
# 66 / /
#  1895  files have been checked
# 67
#   files have been checked
# 1895  files have been checked
#  /  68 files have been checked
# 69 /  189570  files have been checked71/1895    /
# 189572 /73 / 189574 1895  /  files have been checked
# / 1895  files have been checked
#  1895  files have been checked
#  files have been checked
# 75 files have been checked 76 / 1895  files have been checked
#  77/ files have been checked78 79
#  / 18951895/80   files have been checked81
#  files have been checked
# 1895  files have been checked
#  1895  82 / 1895  files have been checked
# /  189583 /84/  / 1895 85  /  files have been checked
#  files have been checked
# 1895  files have been checked
# 1895
#   files have been checked files have been checked1895  files have been checked
# 86/ 1895 / 1895  files have been checked
# 87  88 files have been checked89 /
# 90
# 91
#   /1895  files have been checked
#  / 189592 / 1895  files have been checked
# 93/1895 / 94   files have been checked
#  1895  files have been checked
#   files have been checked
#  // 1895  files have been checked
# 959697 18951895 98 / /  1895  99100 files have been checked
#  files have been checked/    1895 /// 1895   files have been checked
#  1895101 files have been checked  files have been checked
#  files have been checked
#
# 102
# 103 1041895 / 1895  files have been checked
#   files have been checked
# 105/106107/    // // 1895 1895   files have been checked
#  1895  files have been checked
# 1895 1081091895 1895   110  / 1895  files have been checked
#   files have been checked// 1895
#  files have been checked files have been checked
#  1895  files have been checked
# 111
# 112 files have been checked
#  /  files have been checked / 1895  files have been checked
# 1895  files have been checked
# 113 /114
#  115 116/117/ / 1895  files have been checked
#  / 118 119  18951895 /120 / 1895 18951895   files have been checked
# 121  files have been checked
#   files have been checked
#   files have been checked1895/
# / files have been checked  122 files have been checked
#
# 12318951241895     files have been checked
#  /125 files have been checked
# / 1895  files have been checked
#  / / 1895 1895126 127  128129 / 1895  files have been checked
#  files have been checked
# 130 131/ 1895/  / 1895 files have been checked 1895/
#   /   files have been checked
# 1895  files have been checked
#   files have been checked1895  files have been checked files have been checked
# 132
#
# 1895  files have been checked
# / 1895  files have been checked133 / 1895  files have been checked
# 134135
# 136 137138 139  140 / / / // 1895  files have been checked
#  1895  files have been checked1895 1895  files have been checked//
#  1895   files have been checked141
#  / 1895  files have been checked
#  1421895 files have been checked
# 1895
#  143 / 1895  files have been checked
#  / 1895  files have been checked files have been checked144 /
# 145 1895   146147/ files have been checked
#   files have been checked
# 148 /
# 149  1895150 / 1895  files have been checked
#  / /  files have been checked
# 1895 1895 / 1895  files have been checked
# 1895 files have been checked   files have been checked
# 151 / files have been checked
#
# 152153154  1895 // 1895155  files have been checked
#    1895/    files have been checked
# 156  files have been checked
# 157158/ /159    1895  files have been checked
# 1895  files have been checked/1895
#  / 1601895 /  files have been checked
#  / 161 /1621895 18951631895   files have been checked 1895   files have been checked
#   files have been checked1895  files have been checked/
#
#  files have been checked 1895 /
# 164
#  165 files have been checked
#  /  1895  files have been checked
#  files have been checked
# 166167 168 / 1895  files have been checked
# / 1895  files have been checked /169 / 170 1895  files have been checked / 1895
#
#   files have been checked
# 1895171/ 172  /  173  files have been checked
# 18951895//174  / files have been checked175
#   / 1895176  18951771895  files have been checked
#   files have been checked files have been checked
# 1895  files have been checked
#  / files have been checked
#
# 178 179 / /1895  files have been checked
#   1895 1895180181 / 1895  files have been checked  files have been checked
# 182 // 1895 1895  files have been checked
# 183  files have been checked /
#
# 1841895185  /   files have been checked files have been checked1895
#
#    files have been checked186/ 1895  files have been checked  /
# / 187 /1895
#  1895  files have been checked
#  188189 / 1895  files have been checked
#   190191 1895 /  files have been checked
# 192 /1895 193 / 1895  files have been checked
# /  files have been checked
#  194 files have been checked
#  1895 / 195/ 1895  files have been checked
#  1961971895 1895/   files have been checked
# /198  / 1895  / 1895   files have been checked
#  files have been checked1991895
#   files have been checked200 / files have been checked1895  files have been checked
#
#
# 1895201202/ 1895   files have been checked / 1895 / 1895
#  files have been checked
#  files have been checked   files have been checked
# 203
#  /  files have been checked
# 204 205 /1895/206  /1895  1895  files have been checked  files have been checked
# 207208 1895  files have been checked
#  files have been checked
#
# 209210 / / /   189518951895    files have been checked
# 211212  /  files have been checked files have been checked / 1895
# 213/
#  / 1895 1895  files have been checked
#  files have been checked files have been checked 1895
#
# 214215216 / 217218   1895  files have been checked
# /  files have been checked 1895/ / 1895
# 219 / 1895  files have been checked
#   files have been checked
#  / 1895  files have been checked
# 220 / 1895221 / 1895  files have been checked
# 1895  files have been checked
#   files have been checked
# 222 / 1895  files have been checked
# 223  files have been checked 224/ 225 / 1895/  1895  files have been checked files have been checked
#
# 226 1895  /227 / 1895  files have been checked
#  files have been checked
# 228
# 229 /  / 1895230  1895 files have been checked1895  files have been checked
#   files have been checked231
# 232 /
# 233 / 1895  files have been checked
# 234 / 1895 235 / 1895  files have been checked
# 1895236/237 / 1895  files have been checked
#   files have been checked
#   files have been checked
# /1895238   1895 /  2391895  files have been checked/ 1895  files have been checked
#  files have been checked
# /
# 240 /241    / 2421895  files have been checked
# 24318951895 244 245 files have been checked / 1895  files have been checked
# / /  246 files have been checked
#  1895  files have been checked
# 247248
#  files have been checked/
#  1895 /1895  files have been checked / 1895
#   1895  files have been checked
# 249 files have been checked
#   files have been checked
# / 250 / 18951895    files have been checked
# / files have been checked251  2521895
# 1895 / 1895  files have been checked253 254 /  files have been checked
#  255256 / 1895  files have been checked
#  files have been checked
#  /
# 257 /  / 1895  files have been checked
# 1895258/   files have been checked 1895 / 1895
# 259 /260   files have been checked18951895/1895  files have been checked
# 261
#  262/   / 1895263   files have been checked
#  264 /1895 files have been checked  265
# 266 files have been checked
#  files have been checked
# / /1895  files have been checked /
# 267 1895 1895  files have been checked 1895  files have been checked
#   files have been checked
#  1895/268  1895  files have been checked269270  271
#  /  / files have been checked
#  / /1895 18951895  files have been checked1895  files have been checked
# 272 / 1895  files have been checked
#   files have been checked
# 273 / 1895274 / 1895  files have been checked
#
# 275  files have been checked
#   276 /277278/ 1895279  / /  files have been checked
#   files have been checked  / 1895  files have been checked280 /1895
#
# 1895 281  files have been checked282 / 1895  files have been checked
# 1895 1895  files have been checked
#  files have been checked
#
#  files have been checked
# 283 / 1895  files have been checked284 / 1895  files have been checked
#
# / 1895  files have been checked
# 285 /286 1895  / 1895  files have been checked
# 287288289  files have been checked  /290
# 291  files have been checked
#  1895  files have been checked
# / 1895  files have been checked/292 /   1895 / 1895  files have been checked
# 1895  files have been checked
#  files have been checked
#
# 293 / 1895  files have been checked294/
#  295 1895 296297 files have been checked /
#  1895 / / 1895  files have been checked
# 298  / / 18951895  files have been checked299300 1895301  files have been checked302 / 1895 303
#   files have been checked    files have been checked/
#
#  files have been checked/304 /
#  / 1895
#  305/   1895  files have been checked18951895/
#    3061895 files have been checked
#  files have been checked / 1895  files have been checked
# 1895
#   files have been checked
#  files have been checked 307 files have been checked
#  / 308 / 1895 309 1895 files have been checked
#   files have been checked
# 310 / 1895 / 1895
# 311312313314 / files have been checked
# 315   // 1895  files have been checked316 317 files have been checked
# / 1895 318  319  /1895  files have been checked files have been checked
#
#  / 1895
# / 1895  files have been checked
# 1895/320321 1895   files have been checked
# 1895  / / 1895  files have been checked
#   files have been checked  322 /323 1895
# /1895  / files have been checked files have been checked files have been checked files have been checked 1895  files have been checked
#
#
#
# 1895
#  files have been checked
# 324325 /  326 //3271895 / 1895  files have been checked
#  1895  files have been checked
# 328  / 1895 329 files have been checked330331   files have been checked/  332/1895 1895/ /333
#   files have been checked
#
# 1895/18951895   files have been checked  files have been checked
#   1895
#   files have been checked files have been checked334 files have been checked
# 335 / 1895336  / 1895 files have been checked
#
# 337  files have been checked
# / /  1895  files have been checked
# 1895
# 338  /  files have been checked339
#  1895  files have been checked
# / 1895  files have been checked
# 340341342  343 /344 / 1895  files have been checked
# / 345 346 / 1895 1895  files have been checked  files have been checked
# / 1895  files have been checked
#
# 347//  18951895  files have been checked 348349 /  files have been checked
#  1895  files have been checked /
#  1895 / 1895  files have been checked 1895350 351352 353
#  files have been checked/ 1895  files have been checked
#
# 354
#  /355 files have been checked356 / / 1895  /
# /1895 357 1895  files have been checked
#   files have been checked
#  1895 files have been checked
# 358   files have been checked  /
# /  1895 1895 359 files have been checked
# 360361/ /  1895 362 363 / /  /  18951895 1895  files have been checked files have been checked
# 1895 /  files have been checked
#  files have been checked
#  1895  files have been checked
# 364365 366
#   files have been checked
#  files have been checked
#  /367/ /  /   1895 3681895 369 18951895 / 370 /  files have been checked
#  /1895371 1895  files have been checked
#  files have been checked
#  files have been checked
#  files have been checked 1895372  373 / 1895   files have been checked / files have been checked
#
#  files have been checked
# 374 // 1895 1895  files have been checked
#  1895 375 files have been checked
#  1895  / files have been checked
# 376 / 1895  files have been checked
#
#  files have been checked
# 377 378/  379 3801895381  / 1895  files have been checked
# 382 //  files have been checked
# 1895  / /  383 1895 1895 files have been checked384 3851895  files have been checked
# 1895  files have been checked
# / / 1895  files have been checked
# 1895
#  386  files have been checked387388
#  files have been checked
#  files have been checked  / 1895 /389/  390 / 1895
#   files have been checked   files have been checked
#
# /391  39218953931895 / //1895  files have been checked
#  1895394   files have been checked
# / 395 // 1895  files have been checked
#  1895 396  files have been checked 1895  files have been checked / files have been checked
# 397398
#
# 399 / // 1895 1895  files have been checked
#  files have been checked 1895
# 400   files have been checked /4011895
#     files have been checked 1895  files have been checked
# 1895 files have been checked
# 1895   files have been checked
# 402 / 1895/403 files have been checked
#   files have been checked
#
# 404  / 405 / 1895/ 18951895 406 407 / files have been checked
#  408409 files have been checked /  1895  files have been checked
# /1895  files have been checked
#
# 410  files have been checked / / 4114121895
#  /   1895 files have been checked
# 189518951895 413 /414  files have been checked
#   files have been checked /  files have been checked
#   1895  files have been checked
# 415  416
# 1895  files have been checked
# / files have been checked
# / 1895417 418/   1895  /1895 files have been checked 419 /420
# /  /    files have been checked
#  files have been checked1895  files have been checked
# 421 42218951895/
#    423  files have been checked424 /1895 files have been checked/
#   1895 1895  files have been checked
# / files have been checked
#  1895  files have been checked
#
#  files have been checked1895  files have been checked425
# 426
#  / 1895/427 1895428 429430    files have been checked431
#  / 432 / 1895433 1895/  files have been checked/  /  files have been checked
# 434 /   1895
#  / 1895  files have been checked/1895 files have been checked18951895  files have been checked
#  files have been checked435
# 436437  1895
#  / / 1895  files have been checked   1895
#  files have been checked438
#  / / 1895  files have been checked4391895  files have been checked440 /  /
#
#   files have been checked441
# 1895  files have been checked / files have been checked
#
#  files have been checked1895
#
#  442 443444 /  files have been checked
# 445 /  446 / 1895 1895 447448/ 1895/449 files have been checked1895 files have been checked
#   1895
# / 1895  files have been checked
#  files have been checked   files have been checked /450 1895  files have been checked
#  /  / 1895  files have been checked
#
#  files have been checked
#
# 1895  files have been checked451 /
# 452453 / /  454 18951895  files have been checked
# 1895455/ 1895456  files have been checked  / 1895
#  files have been checked
#  / 1895 457458  files have been checked
#  4591895 / files have been checked
#  files have been checked460 //461  1895 / 1895   files have been checked
# 462 files have been checked
#  4631895  files have been checked
#  files have been checked
# 1895  files have been checked
# / /
# 464 /465466 1895  / 1895 /467 /    1895 1895  files have been checked
# / 1895 files have been checked1895  files have been checked files have been checked
#
# 1895  files have been checked
#   files have been checked
# 468469
#  470  /471 / files have been checked / /1895 472 1895
#   1895473/ 1895   files have been checked474  files have been checked
#   files have been checked
#
# 475 /  files have been checked
#  1895/476 / 1895  4771895478 /  files have been checked
#  1895  files have been checked479 files have been checked  files have been checked
# 480 /481
#   1895/   files have been checked
# /
#   18951895  files have been checked1895//  files have been checked
# 482 /   1895
# 18951895   files have been checked
#  files have been checked 483
#  484 files have been checked
#  / / 1895  files have been checked  files have been checked485
#
# 486 1895/ 1895  files have been checked
#   files have been checked487 488
# 489 /  /4904914921895493/ 1895     /  1895/ files have been checked
# /1895    494 files have been checked
#  files have been checked/1895 / 1895 files have been checked
#   files have been checked
#   files have been checked
#
# 495 //  18951895496497 / 1895  files have been checked
#  498 499 / /    files have been checked1895500  1895 files have been checked1895
#    files have been checked/ 501 1895
#
#   files have been checked
# 5021895  files have been checked
#   files have been checked/ 503
# /1895/   files have been checked files have been checked
# / 1895504
# 5051895506 /  / 1895  files have been checked files have been checked
#
# / 1895  files have been checked
#   files have been checked
# 507 508509  / 1895 1895 files have been checked1895  files have been checked
#
#  / 510511 /  1895  files have been checked
# /  files have been checked
# / 512 1895 1895  files have been checked
# 513 / / 1895  files have been checked
# 1895  files have been checked514515 / 1895  files have been checked
# 516
# 517  518 /5191895  files have been checked
#  1895  files have been checked
#   / 520/ / 1895 1895  files have been checked
# / 1895  files have been checked
#   files have been checked
#  1895/  files have been checked 1895  files have been checked521522523
#  / / 1895524 525     files have been checked/ /
#  files have been checked
# / 18951895526  files have been checked
#    files have been checked
#  /5271895 1895 528529 /  1895  files have been checked 530 /
#
#   files have been checked
# 531  / 1895  files have been checked1895 files have been checked
# 1895532/
#  files have been checked
#  1895 / 1895  files have been checked  files have been checked
#  files have been checked533534 535/ 1895/536 / /
#
#  files have been checked
# 1895537 /538 /  1895 1895/  1895  files have been checked 1895  files have been checked1895
#    files have been checked
#  files have been checked
#  539 files have been checked
# 540
#  / 1895  /541 files have been checked 1895  files have been checked542543  /
# /
# /1895 1895544 files have been checked
#  545 /  / 1895 5461895 547 / 1895  files have been checked files have been checked
#  / 18951895
# 548 /  files have been checked
#  files have been checked files have been checked
#  549 /
# 1895 1895 550 551 /  files have been checked
#   files have been checked552 //
#  files have been checked
# 553 /55418951895  files have been checked1895  files have been checked
# 555 /  files have been checked  1895  files have been checked
# 1895 556 files have been checked files have been checked
#
#
#   / 557 / 1895
# 558 / 559 //  files have been checked
# 1895  1895 files have been checked1895  files have been checked
#
#   files have been checked
# 1895 560 files have been checked
# 561562 563564565/566 /  567 568  / 1895 / 1895 18951895 / files have been checked
#   1895   files have been checked
#  // 1895  files have been checked
#  files have been checked files have been checked
#
#   /  files have been checked
# 1895  files have been checked
#  569 1895570 / 571 / 1895/572 573/1895  / 1895  files have been checked
# 574 / 1895  files have been checked
#  575/1895    files have been checked  files have been checked1895
#  /   files have been checked1895 files have been checked
#
#
# 576577 files have been checked1895  / 1895
#   files have been checked
# 578 files have been checked /579
#    580 // files have been checked/ 1895 1895  files have been checked
#
# 1895581582  583 / 18951895584 585 / 1895  files have been checked
#  /   files have been checked
#   1895/  files have been checked  files have been checked
# 1895
# / files have been checked  files have been checked
#  1895586 /
#   files have been checked587  files have been checked
# 588 /
#   / 1895  589590 / files have been checked1895  files have been checked
#  1895
# 5911895 files have been checked
# 592 593 / 1895   files have been checked
# 594  /595  files have been checked/ 1895 596597
#    files have been checked / 1895  files have been checked
# 1895  files have been checked
#
# // 1895  files have been checked
# / 5981895  files have been checked
#  599/ 600601 1895  // / 1895 1895  files have been checked
# 602  files have been checked/
#  / 1895 1895    files have been checked files have been checked
#  1895  files have been checked
# 1895
#  files have been checked
# 603  files have been checked
# 604 / 1895  files have been checked
# 605606 /   // 6071895    files have been checked
# 1895608609 / 1895610/ 1895  files have been checked
# / 611 / 1895  files have been checked
# 1895   files have been checked
#   files have been checked/ 612 /1895 files have been checked613
#  6141895
#  files have been checked
# 615  files have been checked
# / /1895 616 1895  files have been checked
#  1895 /  files have been checked 1895  files have been checked
# 617
#  / 618/ 6191895 files have been checked620 1895
#  / files have been checked / 1895
#  files have been checked  621/  files have been checked622
#  / 1895 /  1895623 /1895
#  1895  files have been checked624625 1895 files have been checked
#  / 1895 626  files have been checked
#  files have been checked627628 /
#   / // files have been checked1895  files have been checked
#
#  files have been checked629630 1895
#
#   /  files have been checked
# 1895  files have been checked 631 / 1895632
# 633 / 18951895  files have been checked  files have been checked
#  files have been checked
# / 1895  1895634 635 files have been checked
#  636/   / / / 1895
# 18951895 files have been checked
# 1895   files have been checked  files have been checked
# 637 files have been checked / 1895
#
# 638639 files have been checked
#   /  /6401895 641   642643 / 1895  files have been checked
#  files have been checked
# 644 / 1895  files have been checked
#  645// files have been checked /1895646 / 1895  files have been checked
#  1895/ 1895  files have been checked
#
#   1895  files have been checked
# 647 /  648 / 18951895 files have been checked649 650 files have been checked  files have been checked
#
#  /651 /  files have been checked1895 652 1895
#
#  files have been checked
# / 1895 653   files have been checked / 1895  files have been checked files have been checked
#
#
# 654 655 //  18951895656 /  files have been checked/ 657658 1895  files have been checked
#  /
# 1895   files have been checked 1895  files have been checked
# 659
#  files have been checked//
#   66018951895 1895  files have been checked
# /    files have been checked1895  files have been checked661662 files have been checked /
#
# /663
#  664 665 /18951895  /   files have been checked  files have been checked
#
# / 666 667 / 1895  files have been checked
# 1895 1895 1895 files have been checked
# 668 /   files have been checked
#  files have been checked
# 6691895670  files have been checked / 1895671
#  / 1895 /   files have been checked672673 / 1895 files have been checked
#  / 1895  1895  674 /  files have been checked675 /676
#  1895 // 1895677 /678  files have been checked  files have been checked
# 1895   files have been checked
#
# 18951895  files have been checked679
#  files have been checked  files have been checked
# / files have been checked
#
#
# 680681 / 1895  files have been checked
# 682  /  / 1895  files have been checked
# 6831895/1895  files have been checked684685   files have been checked
#  686/
#  //1895 1895  1895  files have been checked
#  files have been checked  files have been checked
#
# 687  /  / 1895 18951895 files have been checked
#   688 / 1895 files have been checked689690 691692693/ / 1895  / /  files have been checked
#
#  files have been checked   1895694/
#  files have been checked1895
# 18951895  files have been checked  files have been checked  files have been checked
#  / 1895  files have been checked
#  files have been checked
# 695
#
# 696697698 /  / 1895  files have been checked
# 699 / 1895  /1895 700  /  files have been checked701702 / 18951895  files have been checked
#  /  files have been checked  703 / 704
#  files have been checked18951895  files have been checked
# 1895
# 705 / / 706
# 707 files have been checked708 1895    files have been checked
#
# ///  files have been checked
# 1895709  / /1895  files have been checked1895 1895710  files have been checked
#  1895  files have been checked711
#  /712713  files have been checked1895
#  1895  files have been checked
# // 1895
# 714 / files have been checked / 1895  files have been checked
#  715 /1895  files have been checked
# 716  files have been checked717
#  files have been checked/  18951895
# 718 /7191895/ 1895  files have been checked
#
#     files have been checked
# 720 1895721 files have been checked
# // / 1895   1895 1895  files have been checked
# 722723 files have been checked724 files have been checked   files have been checked // 1895  1895 files have been checked
#  files have been checked
#
# /  files have been checked
#
# 1895725
# 726  /727 files have been checked
#  728 /729730/ 1895  files have been checked
# 731 / 1895  files have been checked
#  // 7321895  files have been checked
#  /  18951895 733    files have been checked files have been checked1895734
#  735//736/  files have been checked
#   18951895  / 1895 1895/737 /  18951895  files have been checked
#   files have been checked
#  files have been checked
#  files have been checked
# 738
#  files have been checked
# /    files have been checked7391895  files have been checked
#
# 740 1895  files have been checked
#  741 /742 / 743 //1895  files have been checked
# 1895  1895 / 1895  files have been checked files have been checked
# 744 745  / / 1895746 1895
#  files have been checked1895  files have been checked747
#
#    / 1895/   files have been checked files have been checked1895
#  files have been checked files have been checked
#
#
# 748749 / / 1895  files have been checked
# 750 751 / 7527531895  1895/754 /  files have been checked 755
#  /   //  files have been checked75618951895  18951895/  files have been checked
#  1895   files have been checked files have been checked
#
#
# 1895  files have been checked757758 / files have been checked
#  files have been checked
# /
# 7591895 / 1895 760761   files have been checked  /1895
# / 1895  files have been checked
#  762 files have been checked  files have been checked
#
# 763764 / 1895 / 1895  files have been checked  1895765 766
#  files have been checked767768 / /   / 1895  files have been checked
# 7691895  files have been checked /
# / files have been checked
# 1895 /
#  18951895  files have been checked
# 770   files have been checked771772
# /1895    /  / files have been checked773 / 1895  files have been checked
# 18951895774 /    files have been checked1895775 / 1895  files have been checked
#  files have been checked776
#
#  / 1895  files have been checked
#   files have been checked
#  files have been checked
# 1895  files have been checked
# 777778 779 /780 1895  files have been checked/ 1895781782  783
# 784 / / 1895 /785
#    files have been checked
# / files have been checked 1895  files have been checked
#
# / 1895   / 1895 files have been checked
# 1895786    files have been checked/1895   787 files have been checked
# 1895  files have been checked
#
#  788/ 1895  files have been checked
#  files have been checked
#  / 789790791 792 / 1895 /793/ / 1895794   1895 1895  files have been checked
#   1895 /  files have been checked795 / files have been checked
#  files have been checked
#
#  /  /796 1895  18951895  797 / 1895  files have been checked
# 1895 files have been checked files have been checked files have been checked798 files have been checked
#
#
# /
#  799 files have been checked800 // 1895 801 / 1895802 /  /
#  1895   803 / files have been checked
# 804 / 18951895  files have been checked
#  files have been checked
#  files have been checked 1895  files have been checked
# 1895805  806 / files have been checked807
# 808
# 809    files have been checked
#  1895/ /1895810      files have been checked
#  files have been checked///1895 1895 1895
#  files have been checked  811 / 1895  files have been checked
#  files have been checked
# 812 / 8131895  files have been checked
#
#  files have been checked814 1895815  816 817 / 1895  files have been checked/ 1895  files have been checked
# / 1895  files have been checked1895
#   files have been checked/ 1895/
#
# 818
#   files have been checked
#  files have been checked
#  1895  files have been checked
#  819820  //  / 821 / 189518951895 8221895 files have been checked /   files have been checked
# 1895  files have been checked   files have been checked
#
#  files have been checked
#
# 823 / 1895  files have been checked
# D:/Sync2/emulators/Pinball FX3/data/steam/SpaceBear2.pxpD:/Sync2/emulators/Pinball FX3/data/steam/TheWalkingDead.pxp
# D:/Sync2/emulators/Pinball FX3/data/steam/Tesla.pxp
#
# D:/Sync2/emulators/Pinball FX3/data/steam/SpaceBear1.pxp
# D:/Sync2/emulators/Pinball FX3/data/steam/STARWARS_SFA.pxp
# D:/Sync2/emulators/Pinball FX3/data/steam/STARWARS_Han_Solo.pxp
# D:/Sync2/emulators/Pinball FX3/data/steam/STARWARS_Droids.pxp
# D:/Sync2/emulators/Pinball FX3/data/steam/STARWARS_Light_VS_Dark.pxpD:/Sync2/emulators/Pinball FX3/data/steam/STARWARS_Rebels.pxp
# D:/Sync2/emulators/Pinball FX3/data/steam/STARWARS_LAPB.pxp
#
# 824 / 1895  files have been checked
# D:/Sync2/emulators/Pinball FX3/data/steam/UNIVERSAL_BTTF.pxp
